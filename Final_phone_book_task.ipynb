# %% [markdown]
# <a href="https://colab.research.google.com/github/ukeshbhaal/Student_DB-Telephone/blob/main/Final_phone_book_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dnspython
# !pip install pymongo[srv] 
import pymongo
import re
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb+srv://ukesh:ukesh123@cluster0.uo8lxtk.mongodb.net/?retryWrites=true&w=majority")
db=client.records
records=db.records

# %%
def phone_number():
  i=0
  while(i==0):
    phone_number1=input("Enter your phone number: \n")
    _phone_number="[6789][0-9]{9}$"
    if re.match(_phone_number,phone_number1):
      i=1
      if (phone_number is not None):
        return(phone_number1)
    else:
      print("***Please enter the valid phone number***\nLike 9044005596")
      i=0
def name():
  i=0
  while(i==0):
    name1=input("Enter your name: \n")
    _name="[A-Z a-z \._-]{2,25}$"
    if re.match(_name,name1):
      if db.records.find_one({"_id":{"$eq":name1}}):
        print("\nAlready Found this Name in Data Base\n")
        home()
      else:
        print("\nYou have entered the valid Name")
        i=1
        if (name is not None):
          return(name1)
    else:
      print("***Please enter the valid name***\nR.ukesh")
      i=0
def mail_id():
  i=0
  while(i==0):
    mail=input("Enter the Email id: \n")
    _mail="^[a-z A-Z]+[\._]?[a-z A-Z 0-9 \._-]+[@]\w+[A-Z a-z]+[.][A-Z a-z]{2,3}$"
    if re.match(_mail,mail):
      print("You have entered a vaild Email id\n")
      i=1
      if (mail_id is not None):
         return(mail)
    else:
      i=0
      print("**Please enter the valid Email id**\nLike-ukesh.r@gmail.com")    
def place():
  i=0
  while(i==0):
    place1=input("Enter the Place : \n")
    _place="[A-Z a-z \._-]{2,30}$"
    if re.match(_place,place1):
      print("You have entered the valid Place")
      i=1
      if (place is not None):
        return(place1)
    else:
      print("\n**Please enter the valid place**\nLike Erode")
      i=0                 
def create():
  i={"_id":name(),"phone_number":phone_number(),"mail_id":mail_id(),"place":place()}
  records.insert_one(i)
def search():
  name1=input("Enter the name or mail ID or Mobile number \n") 
  if db.records.find_one({"$or":[{("_id"):(name1)},{("mail_id"):(name1)},{("phone_number"):((name1))}]}):
    r={"$or":[{("_id"):(name1)},{("mail_id"):(name1)},{("phone_number"):((name1))}]}  
    for x in records.find(r):
     print(x) 
  else:
    print("\nNot found in Data base - Kindly try again")  
    search()
def delete():
  j1=(input("\nHow many contacts do you want to delete\nOnly numbers\n"))
  if j1.isdigit():
    k=1
    j=int(j1)
    if(j>=1):
     while(k<=j):
       name1=input("Enter the name or mail ID or Mobile number \n")
       if({"$or":[{("_id"):((name1))},{("mail_id"):((name1))},{("phone_number"):((name1))}]}):
         r={"$or":[{("_id"):((name1))},{("mail_id"):((name1))},{("phone_number"):((name1))}]}  
         records.delete_one(r)
         print("\nDeleted successfully")
         k=k+1
       else:
         print("Not found\n")
         delete()  
    else:
      print("Enter only numbers\n")    
      delete()
  else:
    print("\nKindly enter only numbers\n")
    delete()    
def display():
  my = records.find({},{"_id":1,"phone_number":1,"mail_id":1,"place":1}).sort("_id") 
  my = pd.DataFrame(my)
  print(my) 
def update():
  id1=input("Enter the name of the contacts\n")
  if db.records.find_one({"_id":{"$eq":id1}}):
    option=input("\nTo edit phone number - Press 1\nTo Edit mail ID - Press 2\nTo edit Place - Press 3\n")
    if(option=="1"):
      i={"$set":{"phone_number":phone_number()}}
      j={"_id":id1}
      records.update_one(j,i)
      print("\n Updated succesfully")
    elif(option=="2"):
      i={"$set":{"mail_id":mail_id()}}
      j={"_id":id1}
      records.update_one(j,i)   
      print("\n Updated succesfully")
    elif(option=="3"):
      i={"$set":{"place":place()}}
      j={"_id":id1}
      records.update_one(j,i)   
      print("\n Updated succesfully")
    else:
      print("Enter only 1 or 2 or 3\n")
      update() 
  else:
   print("Entered name not found in DB \n")
   update()            
def home():
    print("1.To Create new contact - Enter option - 1\n2.To Search - Enter option - 2\n3.To Delete - Enter option - 3\n4.To display Enter option - 4\n5.To Update Enter option - 5\n")
    option=(input("Enter your option \nOnly numbers "))
    if(option=="1"):
        create()
    elif(option=="2"):
        search()
    elif(option=="3"):
        delete()
    elif(option=="4"):
        display()
    elif(option=="5"):
        update()
    else:
        print("Enter the option from 1 to 5\n")
        home()
home()
